# %% [markdown]
# # 2020 BC Election Analysis
#
# ## Abstract
#
# The purpose of the project are using the data scrapt from Tweeter to apply some machine learning models to predict the result of the election. There are serveral training model will applied to the words that the people post on the tweeter. The result that will give to a tweeter for "support" or "not support".
#
# The dataset are driectly scrapt from tweeter with the tweeter developer account. The data will pre-cleaned with serveral ways and the cleaned data will only contains the words.
#
# The python notebook will get the brief instruction of the process that used in the analysis and the use of various methods.
#
# There are total of 4 parts of the data will be extracted from the tweeter, The data that related to the general topics of the election and the topics related to the specific candiantes. The topics "#Biden" and "Trump" are slected to use for general topics. However, although this study are very limited becuase only use one topic for each candiantes but it do conatins large number of the data for each hastages.
#
# This analysis are based on the data that the people post on the tweeter. The project are only used for research.

# %% [markdown]
# ## Geting the data

# %%
#Modele use in the notebook
import tweepy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import re
import preprocessor as p
from collections import Counter
from wordcloud import WordCloud,ImageColorGenerator
from PIL import Image


import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import words
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
#nltk.download('stopwords')
#nltk.download('wordnet')

# %% [markdown]
# ### Get the General Topics

# %%
consumer_key= "2y7uZhIao2b85xXdabo2zltwU"
consumer_secret  = "iMyIFzC5POOCiseEjW3Hf89UVxs5lGKXxpAdv2wBirgHJlM7CJ"
access_token ="1312170158924820481-T79CQNgfrpDqfhCJqeWkr645y4QysX"
access_token_secret= "k1WE2fhLLNJSjuvKTfMZEkAxlURQlq1us21slPBgDaePX"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
# authentication of access token and secret 
auth.set_access_token(access_token, access_token_secret) 
api = tweepy.API(auth,wait_on_rate_limit = True)


date1 = "2020-11-1"
date2 = "2020-11-6"

#post date
date =[]
#user id for the user
user_id = []
#verified or not
verified = []
#user name
user_name = []
#the twitter text
text = []
#user location
location = []
#from which device
source = []
#the data for the followers
likes = []
followers = []
following = []
retweets = []


def get_tweets(date1,date2,word):
    count = 0
    for tweet in tweepy.Cursor(api.search , q=word,count =1000,lang="en",since_id = date1,until = date2).items():
        print(tweet.created_at)
        date.append(tweet.created_at)
        print(tweet.id)
        user_id.append(tweet.id)
        print(tweet.user.verified)
        verified.append(tweet.user.verified)
        print(tweet.user.screen_name)
        user_name.append(tweet.user.screen_name)
        print(tweet.text)
        text.append(tweet.text)
        print(tweet.user.location)
        location.append(tweet.user.location)
        print(tweet.source)
        source.append(tweet.source)
        print(tweet.favorite_count)
        likes.append(tweet.favorite_count)
        print(tweet.user.followers_count)
        followers.append(tweet.user.followers_count)
        print(tweet.user.friends_count)
        following.append(tweet.user.friends_count)
        print(tweet.retweet_count)
        retweets.append(tweet.retweet_count)
    
        print('<--------------------------------------------------->')
        count+=1
        print(count)
    
get_tweets(date1,date2,"#VoteBC"+" -filter:retweets")  
get_tweets(date1,date2,"#BCelxn2020"+" -filter:retweets")
#Zip the data
data1 = list(zip(date,user_id,verified,user_name,text,location,source,likes,followers,following,retweets))
df1 = pd.DataFrame(data =data1, columns =["Date","User.id","Verified","User Name","Tweet",
                                   "Location","Source","Likes","Followers","Following","Retweets"])

df1.to_csv(r'C:\Users\brand\Desktop\Make More Difference\2020 Election Project\Data\BCElection2020.csv',encoding='utf-8')

# %% [markdown]
# #### Processing the Data

# %%
df= pd.read_csv(
    r'C:\Users\brand\Desktop\Make More Difference\2020 Election Project\Biden.csv',error_bad_lines=False)

# %%
#to see the attributes of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183996 entries, 0 to 183995
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  183996 non-null  int64
#  1   Date        183996 non-null  object
#  2   User.id     183996 non-null  int64
#  3   Verified    183996 non-null  bool
#  4   User Name   183996 non-null  object
#  5   Tweet       183996 non-null  object
#  6   Location    131075 non-null  object
#  7   Source      183955 non-null  object
#  8   Likes       183996 non-null  int64
#  9   Followers   183996 non-null  int64
#  10  Following   183996 non-null  int64
#  11  Retweets    183996 non-null  int64
# dtypes: bool(1), int64(6), object(5)
# memory usage: 15.6+ MB

# %%
#as the date are in the type object
df['Date'] = df['Date'].apply(lambda x: dt.datetime.strptime(x,'%Y-%m-%d %H:%M:%S'))

# %%
#check the sucessful of the datetime
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183996 entries, 0 to 183995
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  183996 non-null  int64
#  1   Date        183996 non-null  datetime64[ns]
#  2   User.id     183996 non-null  int64
#  3   Verified    183996 non-null  bool
#  4   User Name   183996 non-null  object
#  5   Tweet       183996 non-null  object
#  6   Location    131075 non-null  object
#  7   Source      183955 non-null  object
#  8   Likes       183996 non-null  int64
#  9   Followers   183996 non-null  int64
#  10  Following   183996 non-null  int64
#  11  Retweets    183996 non-null  int64
# dtypes: bool(1), datetime64[ns](1), int64(6), object(4)
# memory usage: 15.6+ MB

# %%
#to check if there are any null rows in the dataset
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Date              0
# User.id           0
# Verified          0
# User Name         0
# Tweet             0
# Location      52921
# Source           41
# Likes             0
# Followers         0
# Following         0
# Retweets          0
# dtype: int64

# %% [markdown]
# The null result will not have significant influence to the data analysis
#
#
#
#
# ### Data Clean Process
#
# Starting from here, the following part are aiming using the processor to clean the dataset. The main point to do this process is to delete the symbols or other elements except words. Then we can traning the words sets as positive or negative.
#
# As for setting the processor, the emojis, usernames,URLS, hashtages and RT(reserved words) will be deleted.

# %%
#setting the processor 
p.set_options(p.OPT.URL, p.OPT.EMOJI,p.OPT.MENTION,p.OPT.HASHTAG,p.OPT.RESERVED)

#Creat a new column named "Cleaned Tweet" stores the tweeter after processing
df['Cleaned Tweet']=[p.clean(i) for i in df['Tweet']]

#show the result
df['Cleaned Tweet']
# Out:
# 0          Biden - 290 Trump - 248 Easy money babbyyyyyyy!!
# 1         Votes get whittled down? Counting of mail in b...
# 2         He has to have evidence if he is to present to...
# 3         You jump the gun every time ! So desperate to ...
# 4         You are deluded. is going to bring to USA. Get...
#                                 ...
# 183991                 My Mom and I voted on Sunday for !!!
# 183992    LOL. because it's a lie. Things only trend whe...
# 183993    Tell us how your really feel, Pia-don't hold a...
# 183994    So many loonies working themselves up into a t...
# 183995                 Voting in NY for the first time!!!!!
# Name: Cleaned Tweet, Length: 183996, dtype: object

# %% [markdown]
# In order to analysis the data, we might need to converting to the lower case and also remove the punctuations

# %%
#converting to lower case
df['Cleaned Tweet']=[i.lower() for i in df['Cleaned Tweet']]

#remove the punctuations
df['Cleaned Tweet']=[re.sub('[^a-zA-Z]',' ',i) for  i in df['Cleaned Tweet']]

df['Cleaned Tweet']
# Out:
# 0          biden       trump       easy money babbyyyyyyy
# 1         votes get whittled down  counting of mail in b...
# 2         he has to have evidence if he is to present to...
# 3         you jump the gun every time   so desperate to ...
# 4         you are deluded  is going to bring to usa  get...
#                                 ...
# 183991                 my mom and i voted on sunday for
# 183992    lol  because it s a lie  things only trend whe...
# 183993    tell us how your really feel  pia don t hold a...
# 183994    so many loonies working themselves up into a t...
# 183995                 voting in ny for the first time
# Name: Cleaned Tweet, Length: 183996, dtype: object

# %% [markdown]
# Upon now,  the data are showing we might have duplicated tweeters. This is because may be some hot sentances or slogon are using for many tweeters.

# %%
#detecting the duplicate tweeters
df['Cleaned Tweet'].duplicated().sum()
# Out:
# 22569

# %%
#drop the duplicates
df = df.drop_duplicates(subset = 'Cleaned Tweet', keep = 'first',ignore_index = True)
df.shape
# Out:
# (161427, 13)

# %% [markdown]
# ## Data Analysis
#
# ### Visulization
#
# First we need to see how many tweeters are posting for each day from 10-11-2020 to 10-19-2020

# %%
Numbers_of_tweet_each_day=df['Date'].dt.date.value_counts(sort=False).sort_index()
Numbers_of_tweet_each_day
# Out:
# 2020-10-29     9164
# 2020-10-30     9751
# 2020-10-31    10046
# 2020-11-01    11420
# 2020-11-02    16606
# 2020-11-03    24813
# 2020-11-04    48745
# 2020-11-05    30882
# Name: Date, dtype: int64

# %%
fig = plt.figure(figsize = (15,7))
Numbers_of_tweet_each_day.plot.bar()
plt.xticks(range(len(Numbers_of_tweet_each_day)))
plt.xlabel("Day")
plt.ylabel("Count Of Tweets")
plt.title("Count Of posted Tweets On Each Day")
# Out:
# Text(0.5, 1.0, 'Count Of posted Tweets On Each Day')

# %% [markdown]
# Here we can find that the 2020-11-4 has the most number of the tweeters being posted. That is the official start vote day.

# %% [markdown]
# #### Word cloud
#
# Then we can output the most common words in the tweeter,  and we selected most 100 words except the stop words

# %%
#set the stop words
stop_words=set(stopwords.words('english'))
stop_words=list(stop_words)
#add more customized stop words
customized_stop_words=['Election','votes','poli','election','elxn','station']
stop_words=stop_words+customized_stop_words
print(stop_words)
# Out:
# ['t', "needn't", "shan't", 'same', 'nor', 'as', 'own', 'these', 'what', 'while', 'only', 'them', 'not', 'again', 'has', 'any', "should've", "hasn't", 'than', 'your', 'hers', 'ma', 'himself', "wouldn't", 'or', 'will', 'if', 'under', 'couldn', 'down', 'an', 'for', 'she', 'after', 'in', 'out', 'ours', "wasn't", 'a', 'both', 'd', "won't", 'just', 'ourselves', 'won', 'it', 'its', 'who', 'his', 'but', 'most', 'very', 'shan', 'wouldn', 'been', 'themselves', 'needn', 'by', 'few', 'don', 'doing', 'our', 'between', "hadn't", 'the', 'with', 's', 'too', 'on', 'had', 'until', 'below', 'above', 'can', 'haven', 'how', 'of', 'each', 'about', 'you', 'itself', 'all', 'her', 'where', "it's", 'o', 'here', 'against', 'ain', 'now', "aren't", 'isn', 'and', 'mustn', "she's", 'being', 'll', 'at', 'once', 'hadn', 'myself', 'some', 'no', "haven't", "mightn't", 'is', 'we', 'am', 'wasn', 'over', 'those', 'up', 've', 'this', "you'd", 'because', 'mightn', 'through', 'to', 'then', 'aren', 'him', 'hasn', 'did', 'were', 'other', "doesn't", "you're", 'yourself', 'weren', "weren't", 're', 'when', 'i', 'during', "isn't", 'are', 'was', 'does', 'off', "you've", "mustn't", "you'll", "don't", 'doesn', 'so', 'they', 'm', 'my', 'into', 'do', "shouldn't", 'before', 'from', 'shouldn', 'that', 'me', 'yourselves', "didn't", 'herself', 'whom', 'he', "couldn't", 'didn', 'which', 'there', 'be', 'further', 'why', "that'll", 'having', 'more', 'their', 'y', 'have', 'yours', 'should', 'theirs', 'such', 'Election', 'votes', 'poli', 'election', 'elxn', 'station']

# %%
# then remove the stop words from the tweet
df['Cleaned Tweet']=df['Cleaned Tweet'].apply(lambda x:' '.join(w for w in x.split()if w not in stop_words))

# %%
tweet_tokenizer = TweetTokenizer()
df['Cleaned Tweet']=df['Cleaned Tweet'].apply(lambda x:tweet_tokenizer.tokenize(x))

# %% [markdown]
# ##### Tokenizing
#
# After set the the stop words, we need to do the tokenizing, for tweeter, it is best to use the tweetTokenizer

# %% [markdown]
# ##### Stemming
#
#
# As we can see from above, there are some token are shows as "b","c" or other not a good words, but we still need to clean it, Let us try stemming and Lemmatisation to see if they can catch the errors or not. Aslo, stemming and lemmatisation will return the words to a general phrase.

# %%
stemmer=PorterStemmer()

df['Cleaned Tweet'] = df['Cleaned Tweet'].apply(lambda x: [stemmer.stem(words) for words in x])

# %%
Lemmatizer=WordNetLemmatizer()
df['Cleaned Tweet']=df['Cleaned Tweet'].apply(lambda x: [Lemmatizer.lemmatize(words) for words in x])

# %% [markdown]
# The next step is to split the sentance to words and store in a list, remove the duplicated words.

# %%
Cleaned_Tweet=df['Cleaned Tweet']
Cleaned_Tweet.tolist()
# Out:
# ',
#   'europ',
#   'thank',
#   'make',
#   'w'],
#  ['ghost', 'john', 'mccain', 'need', 'close'],
#  ['control', 'year', 'watch', 'mcconnel', 'v', 'obama', 'know'],
#  ['tune',
#   'pm',
#   'watch',
#   'give',
#   'last',
#   'speech',
#   'white',
#   'hous',
#   'lame',
#   'duck'],
#  ['cnn', 'joy', 'watch'],
#  ['state', 'get'],
#  ['earn',
#   'xlm',
#   'coinbas',
#   'take',
#   'short',
#   'quiz',
#   'refer',
#   'other',
#   'use',
#   'invit',
#   'link'],
#  ['trump', 'make', 'remark', 'pm', 'et', 'accord'],
#  ['gain',
#   'vote',
#   'count',
#   'grind',
#   'trump',
#   'clan',
#   'lawsuit',
#   'want',
#   'emphas',
#   'purpos'],
#  ['disappoint', 'grandpa', 'vote', 'biden', 'aliv', 'staunch', 'republican'],
#  ['break', 'news', 'mail', 'put', 'top', 'win', 'know', 'putti'],
#  ['squeaki',
#   'bottom',
#   'time',
#   'torus',
#   'hq',
#   'even',
#   'dumdum',
#   'wishin',
#   'nicer'],
#  ['rate', 'next', 'philli', 'updat', 'could', 'put', 'lead'],
#  ['elect', 'biden', 'serv', 'year', 'becom', 'p'],
#  ['live',
#   'scumbag',
#   'deservedli',
#   'lose',
#   'scumbag',
#   'mail',
#   'ballot',
#   'voter',
#   'fraud'],
#  ['biden', 'ttump', 'tommi', 'tuton'],
#  ['poor', 'kid', 'bright', 'talent', 'white', 'kid'],
#  ['forfeit', 'cheat', 'fine', 'big'],
#  ['medium', 'fire', 'disast', 'nobodi', 'interest', 'tweet', 'anymor', 'cl'],
#  ['polit',
#   'scientist',
#   'say',
#   'part',
#   'what',
#   'help',
#   'get',
#   'woman',
#   'elect',
#   'reject',
#   'notion',
#   'wait',
#   'turn'],
#  ['true', 'phone', 'book', 'need', 'still', 'turn', 'close', 'way'],
#  ['middl',
#   'eastern',
#   'peopl',
#   'think',
#   'trump',
#   'better',
#   'think',
#   'bad',
#   'entir',
#   'globe',
#   'bad',
#   'fu'],
#  ['see', 'guy', 'pennsylvania', 'sign', 'languag', 'press', 'confer'],
#  ['strong'],
#  ['hope', 'trump', 'speech', 'min', 'conced'],
#  ['que', 'presidenti', 'tantrum', 'pm', 'harri'],
#  ['result', 'outcom', 'make', 'peopl', 'happi'],
#  ['hug', 'hope', 'make', 'america', 'great'],
#  ['watch', 'day', 'night', 'slept', 'start', 'noon', 'watch', 'lo'],
#  ['love',
#   'small',
#   'littl',
#   'woman',
#   'make',
#   'look',
#   'bigger',
#   'rub',
#   'kiss',
#   'camera',
#   'pervert',
#   'pig',
#   'bid'],
#  ['yet', 'stand', 'loot', 'kill', 'burn'],
#  ['sicken'],
#  ['dertimin', 'stir', 'pot', 'negoti', 'interf', 'elect', 'ban'],
#  ['joe', 'win'],
#  ['know',
#   'calm',
#   'time',
#   'past',
#   'sever',
#   'day',
#   'tonight',
#   'realli',
#   'worri',
#   'look',
#   'cl'],
#  ['real', 'fraud', 'see', 'aint', 'leav', 'let', 'gooo'],
#  ['dump',
#   'dick',
#   'drive',
#   'around',
#   'flag',
#   'folk',
#   'get',
#   'learn',
#   'vote',
#   'ta'],
#  ['put', 'head', 'pike', 'warn', 'trump', 'crazi', 'a', 'gang', 'warn'],
#  ['trump',
#   'speak',
#   'tonit',
#   'gonna',
#   'crazi',
#   'rant',
#   'gonna',
#   'tri',
#   'power',
#   'grab',
#   'im',
#   'bet'],
#  ['heffa', 'parad', 'act', 'differ', 'whew', 'chile', 'stick', 'favori'],
#  ['hour',
#   'away',
#   'turn',
#   'democrat',
#   'presidenti',
#   'nomine',
#   'democrat',
#   'vice',
#   'presidenti',
#   'nomi'],
#  ['post', 'instagram', 'win'],
#  ['import',
#   'suggest',
#   'second',
#   'major',
#   'network',
#   'project',
#   'biden',
#   'biden',
#   'need',
#   'move',
#   'like'],
#  ['econom', 'issu', 'crosshair'],
#  ['earlier', 'friend', 'pa', 'pa', 'keep', 'faith', 'mail', 'count'],
#  ['address',
#   'nation',
#   'thirti',
#   'min',
#   'address',
#   'doubtless',
#   'sharp',
#   'contrast',
#   'tone',
#   'adap'],
#  ['outsid',
#   'everyon',
#   'hate',
#   'america',
#   'enemi',
#   'america',
#   'everyon',
#   'want',
#   'see',
#   'america',
#   'destroy'],
#  ['realiz', 'trump', 'recal', 'hospit', 'recent', 'like'],
#  ['trump',
#   'point',
#   'behind',
#   'week',
#   'ago',
#   'biden',
#   'win',
#   'landslid',
#   'donald',
#   'pump',
#   'close',
#   'gap',
#   'compet'],
#  ['agre', 'know', 'want', 'everi', 'vote', 'count', 'full', 'effect'],
#  ['democrat', 'outspent', 'republican', 'across', 'board'],
#  ['yooo',
#   'dont',
#   'live',
#   'u',
#   'donaldd',
#   'show',
#   'true',
#   'colour',
#   'youd',
#   'think',
#   'hed',
#   'desper',
#   'enough',
#   'claim'],
#  ['u',
#   'say',
#   'u',
#   'victim',
#   'deepest',
#   'document',
#   'report',
#   'travesti',
#   'justic',
#   'time',
#   'amp',
#   'n'],
#  ['win', 'year', 'later'],
#  ['mvumulivu',
#   'hula',
#   'mbivu',
#   'patient',
#   'persev',
#   'person',
#   'get',
#   'eat',
#   'someth'],
#  ['watch',
#   'actual',
#   'lose',
#   'damn',
#   'mind',
#   'want',
#   'play',
#   'macho',
#   'man',
#   'right',
#   'announc',
#   'win',
#   'th'],
#  ['mayb', 'that', 'peopl', 'vote', 'peopl', 'want'],
#  ['live',
#   'podcast',
#   'unleash',
#   'jeremi',
#   'hanson',
#   'fate',
#   'countri',
#   'hang',
#   'hand',
#   'attorney',
#   'counter'],
#  ['confirm',
#   'live',
#   'edinburgh',
#   'scotland',
#   'mani',
#   'peopl',
#   'slept',
#   'much',
#   'either',
#   'thi'],
#  ['watch',
#   'tonight',
#   'check',
#   'last',
#   'night',
#   'relief',
#   'although',
#   'like',
#   'numb'],
#  ['trump'],
#  ['need', 'bother', 'kick', 'u', 'mani', 'leav', 'drove', 'regi'],
#  ['total', 'fraud'],
#  ['trump',
#   'would',
#   'introduc',
#   'framework',
#   'presid',
#   'mandat',
#   'serv',
#   'minimum',
#   'term',
#   'con'],
#  ['love', 'graphic', 'explain', 'everyth', 'perfectli', 'win'],
#  ['nevada', 'poll', 'worker', 'open', 'ballot'],
#  ['republican',
#   'gain',
#   'hous',
#   'seat',
#   'lose',
#   'presid',
#   'lot',
#   'peopl',
#   'vote',
#   'amp',
#   'republ'],
#  ['wait', 'worst', 'part'],
#  ['creepi',
#   'pedo',
#   'joe',
#   'never',
#   'make',
#   'white',
#   'hous',
#   'fact',
#   'check',
#   'peopl',
#   'spiritu',
#   'realm'],
#  ['shortli', 'result'],
#  ['omg', 'guy'],
#  ['new',
#   'name',
#   'usd',
#   'dollar',
#   'first',
#   'time',
#   'see',
#   'begin',
#   'end',
#   'usd',
#   'supremaci'],
#  ['stop', 'tweet', 'make', 'look', 'like', 'complet', 'loser', 'shut'],
#  ['real'],
#  ['say', 'voter', 'count', 'find', 'new', 'peopl', 'v'],
#  ['earn',
#   'oxt',
#   'coinbas',
#   'take',
#   'short',
#   'quiz',
#   'refer',
#   'other',
#   'use',
#   'invit',
#   'link'],
#  ['interest', 'thread', 'role', 'commun', 'activ', 'peopl', 'colour', 'help'],
#  ['woman', 'vote', 'biden'],
#  ['well',
#   'said',
#   'greg',
#   'donald',
#   'never',
#   'go',
#   'retir',
#   'drive',
#   'nut',
#   'cours'],
#  ['captain', 'need', 'immedi', 'remov', 'polic', 'forc', 'regardless'],
#  ['differ', 'pennsylvania', 'drop', 'shrink', 'game'],
#  ['amp', 'well', 'cabl', 'channel', 'oper', 'decis', 'desk', 'part', 'nation'],
#  ['editori', 'cartoon', 'chip', 'bok'],
#  ['bitcoin',
#   'today',
#   'u',
#   'dollar',
#   'close',
#   'today',
#   'good',
#   'luck',
#   'pay',
#   'bill'],
#  ['ye',
#   'campaign',
#   'current',
#   'conspiraci',
#   'democrat',
#   'state',
#   'offici',
#   'medium',
#   'commit',
#   'fraud'],
#  ['realli', 'hate', 'presid', 'mean', 'noth', 'lol'],
#  ['bring', 'noth', 'see'],
#  ['look', 'back', 'campaign', 'noth', 'make', 'sen', 'tri'],
#  ['rememb', 'day', 'tweet', 'fun', 'thing', 'fatti'],
#  ['pa',
#   'senat',
#   'demonstr',
#   'complet',
#   'lack',
#   'backbon',
#   'refus',
#   'acknowledg',
#   'tha'],
#  ['need', 'remain', 'mail', 'in', 'win', 'k', 'get', 'win', 'k', 'win', 'k'],
#  ['trump',
#   'set',
#   'voter',
#   'fraud',
#   'page',
#   'onlin',
#   'would',
#   'terribl',
#   'got',
#   'inund',
#   'fals',
#   'report',
#   'dem'],
#  ['big', 'updat', 'biden', 'need', 'rd', 'got', 'virtual', 'exactli'],
#  ['fact',
#   'ahead',
#   'almost',
#   'million',
#   'amp',
#   'receiv',
#   'candid',
#   'u',
#   'histo'],
#  ['heck', 'go'],
#  ['definit',
#   'good',
#   'presid',
#   'come',
#   'america',
#   'mistak',
#   'granddaught',
#   'dead'],
#  ['that', 'got', 'vote', 'care', 'everyon'],
#  ['realiz', 'updat', 'page', 'everi', 'im', 'still', 'ob', 'refresh', 'page'],
#  ['editori', 'cartoon', 'malcolm', 'may'],
#  ['look', 'like', 'georgia', 'win', 'k', 'one', 'finish', 'yet'],
#  ['go',
#   'wake',
#   'tomorrow',
#   'win',
#   'that',
#   'kinda',
#   'cool',
#   'one',
#   'big',
#   'step',
#   'get',
#   'shit'],
#  ['got', 'million', 'realli', 'well', 'bloodi', 'medusa'],
#  ['come', 'hear', 'poll', 'number', 'fabric', 'substanti', 'win'],
#  ['shit', 'show', 'pm'],
#  ['vote', 'plea', 'answer', 'retweet'],
#  ['someon',
#   'told',
#   'year',
#   'ago',
#   'unit',
#   'state',
#   'presid',
#   'say',
#   'might',
#   'think',
#   'person',
#   'delusion'],
#  ['dont', 'count', 'arent', 'sentiment', 'like', 'defin', 'legaci', 'wel'],
#  ['correct', 'referendum', 'win', 'record', 'vote', 'count', 'amp', 'margin'],
#  ['still', 'gt', 'like', 'ballot', 'two', 'metro', 'area', 'count', 'abo'],
#  ['steal'],
#  ['thought', 'trade', 'place', 'biden', 'mia', 'sinc', 'tuesday', 'move'],
#  ['wake', 'time'],
#  ['bore', 'american', 'say', 'speak', 'countri', 'english', 'presid', 'often'],
#  ['remind',
#   'want',
#   'ban',
#   'straw',
#   'nationwid',
#   'also',
#   'rig',
#   'mail',
#   'ballot',
#   'make'],
#  ['u', 'three', 'viral', 'vote', 'claim', 'fact', 'check'],
#  ['meanwhil'],
#  ['ran', 'two', 'oppon', 'neither', 'face', 'crook', 'medium', 'damn', 'viru'],
#  ['look', 'stride', 'count', 'dem', 'hate', 'internet', 'dk', 'biden'],
#  ['earn',
#   'comp',
#   'coinbas',
#   'take',
#   'short',
#   'quiz',
#   'refer',
#   'other',
#   'use',
#   'invit',
#   'link'],
#  ['win',
#   'name',
#   'rbg',
#   'john',
#   'lewi',
#   'john',
#   'mccain',
#   'georg',
#   'floyd',
#   'ahmaud'],
#  ['perfect', 'time', 'buy', 'rare', 'via'],
#  ['fake', 'news', 'propag', 'right', 'yet', 'dumb', 'usual', 'mani'],
#  ['folk', 'vote', 'ralli', 'one', 'ralli', 'noth', 'chrysler', 'jeep', 'e'],
#  ['never',
#   'believ',
#   'would',
#   'fox',
#   'deliv',
#   'u',
#   'evil',
#   'modern',
#   'retel',
#   'goo'],
#  ['get', 'fuck', 'outta'],
#  ['would', 'fuck', 'hilari', 'network', 'break', 'call'],
#  ['trump', 'appar', 'give', 'statement', 'min', 'comedi', 'gold'],
#  ['plea', 'blow', 'tweet', 'liter', 'follow', 'need', 'answer'],
#  ['funni', 'mention', 'fraud', 'call', 'project', 'go', 'go'],
#  ['show', 'face', 'hide', 'behind', 'justic', 'peac', 'say', 'name', 'kamala'],
#  ['mock', 'peopl', 'take', 'time', 'make', 'zoom', 'call', 'young', 'man'],
#  ['path',
#   'victori',
#   'remain',
#   'differ',
#   'doabl',
#   'mail',
#   'red',
#   'counti',
#   'goe'],
#  ['oh',
#   'told',
#   'older',
#   'sister',
#   'fb',
#   'page',
#   'must',
#   'pray',
#   'trump',
#   'call'],
#  ['k',
#   'deficit',
#   'base',
#   'mail',
#   'ratio',
#   'wi',
#   'mi',
#   'ga',
#   'pretti',
#   'clear',
#   'win'],
#  ['cheek', 'say', 'anyth', 'huge', 'divis', 'u', 'k', 'probabl', 'wors'],
#  ['perhap',
#   'time',
#   'republican',
#   'conserv',
#   'claim',
#   'biden',
#   'presid',
#   'let',
#   'biden',
#   'way'],
#  ['win', 'four', 'year', 'style', 'substanc', 'obamanom', 'str'],
#  ['record', 'potu', 'candid', 'far', 'behind', 'though'],
#  ['need', 'normal', 'life'],
#  ['bankrupt', 'call', 'that', 'promis'],
#  ['choos',
#   'nikki',
#   'hayley',
#   'femal',
#   'run',
#   'mate',
#   'combat',
#   'kamala',
#   'harri',
#   'see',
#   'year'],
#  ['yousef', 'one', 'open', 'goal'],
#  ['funni',
#   'million',
#   'file',
#   'unemploy',
#   'across',
#   'state',
#   'job',
#   'count',
#   'k',
#   'ballot'],
#  ['idiot', 'believ', 'believ', 'vote', 'fraud', 'parasit', 'mind'],
#  ['fact',
#   'still',
#   'chanc',
#   'win',
#   'even',
#   'seem',
#   'clear',
#   'next',
#   'u',
#   'presid'],
#  ['vote', 'mama', 'sun'],
#  ['biden', 'presid'],
#  ['ahh', 'see'],
#  ['trump', 'biden'],
#  ['better', 'job'],
#  ['tryna', 'give', 'tho'],
#  ['night', 'drink', 'biden', 'win'],
#  ['roller',
#   'coaster',
#   'ride',
#   'amp',
#   'price',
#   'back',
#   'amp',
#   'forth',
#   'vote',
#   'amp',
#   'ballot',
#   'count',
#   'amp'],
#  ['break', 'news', 'trump', 'hold', 'press', 'confrenc', 'live'],
#  ['word'],
#  ['one', 'trump', 'son', 'alleg', 'want', 'cheat', 'father', 'rig'],
#  ['live',
#   'cgtn',
#   'dan',
#   'william',
#   'detroit',
#   'rival',
#   'protest',
#   'count',
#   'center',
#   'detroit',
#   'c'],
#  ['go', 'far', 'v'],
#  ['partner',
#   'china',
#   'invad',
#   'japan',
#   'biden',
#   'presidenti',
#   'futur',
#   'worst',
#   'east',
#   'asia'],
#  ['think',
#   'would',
#   'highli',
#   'enlighten',
#   'interview',
#   'anyon',
#   'age',
#   'vote'],
#  ['want', 'check', 'see', 'year', 'old', 'man', 'exist', 'cast', 'vote'],
#  ['found', 'manufactur', 'even', 'given', 'tim'],
#  ['think'],
#  ['nevada', 'done', 'deal'],
#  ['next', 'longer', 'need', 'deal'],
#  ['rough', 'calcul', 'yesterday', 'estim', 'percentag', 'count', 'base'],
#  ['keep', 'tell', 'frump'],
#  ['end', 'speech', 'line', 'speech'],
#  ['whine',
#   'bondi',
#   'lewandowski',
#   'need',
#   'let',
#   'make',
#   'circu',
#   'philadelphia',
#   'v'],
#  ['long',
#   'take',
#   'count',
#   'much',
#   'time',
#   'atleast',
#   'ppl',
#   'would',
#   'taken',
#   'oath',
#   'amp',
#   'resign',
#   'india'],
#  ['updat',
#   'gain',
#   'k',
#   'mail',
#   'ballot',
#   'left',
#   'finish',
#   'count',
#   'accordin'],
#  ['look', 'like', 'project', 'win', 'k', 'assum', 'inclu'],
#  ['like', 'put', 'bit', 'messag', 'follow', 'end', 'world', 'trump'],
#  ['thank',
#   'poll',
#   'worker',
#   'throw',
#   'ballot',
#   'away',
#   'replac',
#   'ballot',
#   'imagin',
#   'much'],
#  ['basic', 'get', 'postal', 'vote', 'beat'],
#  ['alreadi', 'surrend'],
#  ['websit',
#   'say',
#   'k',
#   'left',
#   'deep',
#   'blue',
#   'philadelphia',
#   'counti',
#   'win',
#   'wel'],
#  ['remain', 'carri', 'montgomeri', 'co', 'mean'],
#  ['thing', 'wors', 'covid', 'would', 'biden'],
#  ['mani', 'clark', 'counti', 'nevada', 'thank', 'amaz', 'work', 'amount'],
#  ['claim',
#   'joe',
#   'eulog',
#   'kkk',
#   'grand',
#   'wizard',
#   'former',
#   'senat',
#   'robert',
#   'byrd',
#   'funer'],
#  ['az', 'ahead', 'nearli', 'million', 'nv', 'lead', 'around'],
#  ['senil', 'win', 'economi', 'go', 'hell'],
#  ['presid', 'donald', 'lead', 'drop', 'le', 'ballot', 'continu', 'count'],
#  ['like', 'new', 'presid', 'encourag', 'confront', 'past'],
#  ['small',
#   'time',
#   'span',
#   'briefli',
#   'thought',
#   'would',
#   'win',
#   'texa',
#   'feel',
#   'like',
#   'month',
#   'ago'],
#  ['v', 'amp', 'happen', 'vega', 'stay', 'vega'],
#  ['joke',
#   'go',
#   'pretti',
#   'soon',
#   'trump',
#   'abl',
#   'enter',
#   'white',
#   'hous',
#   'biden'],
#  ['dear',
#   'joe',
#   'move',
#   'kindli',
#   'find',
#   'presid',
#   'barack',
#   'obama',
#   'portrait',
#   'hang',
#   'sh'],
#  ['im', 'laugh', 'nervou', 'af'],
#  ['lol', 'even', 'lose', 'realli', 'peopl', 'cannot', 'fathom'],
#  ['love', 'small', 'littl', 'woman', 'make', 'look', 'bigger', 'rub', 'kiss'],
#  ['commun', 'tweet', 'thing', 'stand', 'manag', 'win', 'p'],
#  ['wonder',
#   'must',
#   'hold',
#   'amp',
#   'increas',
#   'number',
#   'save',
#   'countri',
#   'disastr'],
#  ['believ', 'biden', 'dem', 'dat', 'dem', 'faith', 'v', 'fait'],
#  ['well', 'vote', 'everi', 'war', 'last', 'yr', 'stop'],
#  ['nicola',
#   'ceauescu',
#   'found',
#   'run',
#   'friend',
#   'last',
#   'day',
#   'helicopt',
#   'evacu',
#   'f'],
#  ['never', 'presid'],
#  ['need', 'better', 'test', 'commit', 'get', 'better', 'test', 'testi'],
#  ['yet'],
#  ['ifi',
#   'done',
#   'calcul',
#   'right',
#   'think',
#   'beaten',
#   'total',
#   'electoralcolleg',
#   'vote',
#   'last',
#   'time'],
#  ['american', 'write', 'guy', 'serial', 'killer'],
#  ['remind', 'tri', 'obfusc', 'embarrass', 'help', 'orchestr', 'amp'],
#  ['liber', 'suck', 'life'],
#  ['indic', 'seem', 'point', 'win', 'pa', 'also', 'nv', 'nc', 'ga', 'wont'],
#  ['person', 'woman', 'man', 'camera', 'tv', 'oh', 'presid'],
#  ['last',
#   'time',
#   'candid',
#   'u',
#   'presidenti',
#   'number',
#   'letter',
#   'last',
#   'name'],
#  ['take', 'plane', 'exil', 'could'],
#  ['foreign', 'newspap', 'az', 'column', 'toast', 'pa', 'lead'],
#  ['man',
#   'live',
#   'la',
#   'vega',
#   'count',
#   'damn',
#   'amp',
#   'stop',
#   'talk',
#   'readi',
#   'nv',
#   'result',
#   'stop',
#   'w'],
#  ['score', 'key'],
#  ['great', 'even', 'program'],
#  ['explain', 'exactli', 'result', 'delay', 'key', 'state'],
#  ['he', 'go', 'even', 'hungov', 'tomorrow', 'win', 'realis', 'finish', 'get'],
#  ['k', 'left', 'count', 'strike', 'rate', 'win', 'k', 'st'],
#  ['seem', 'kany', 'west', 'request', 'recount', 'state', 'except', 'alaska'],
#  ['monitor', 'look', 'pm', 'still', 'lead', 'small', 'margin'],
#  ['k', 'left', 'need', 'win', 'remain', 'win', 'far'],
#  ['look', 'like', 'go', 'take', 'pa', 'k', 'margin', 'that', 'joe', 'need'],
#  ['time', 'wait', 'orang', 'squeez'],
#  ['would', 'like', 'state', 'record', 'latinx', 'voter', 'went', 'point'],
#  ['funni', 'give', 'option'],
#  ['biden',
#   'say',
#   'god',
#   'bless',
#   'troop',
#   'get',
#   'piss',
#   'vote',
#   'send',
#   'die',
#   'iraq',
#   'war'],
#  ['ye', 'get', 'count', 'today'],
#  ['nevada', 'count', 'ballot'],
#  ['great',
#   'fall',
#   'day',
#   'like',
#   'play',
#   'dad',
#   'n',
#   'like',
#   'bein',
#   'around',
#   'em',
#   'get',
#   'decid',
#   'ur',
#   'day',
#   'wi'],
#  ['censor',
#   'taken',
#   'everi',
#   'major',
#   'social',
#   'medium',
#   'outlet',
#   'everyon',
#   'must',
#   'see'],
#  ['im', 'done'],
#  ['matter',
#   'ultim',
#   'rule',
#   'law',
#   'long',
#   'judiciari',
#   'follow',
#   'neither',
#   'candid',
#   'caus',
#   'claim'],
#  ['biden', 'launch', 'presidenti', 'transit', 'websit'],
#  ['play', 'game', 'amp', 'knock', 'trump', 'fr'],
#  ['that', 'roll', 'that', 'lose', 'streak'],
#  ['everyon', 'famili', 'support', 'trump', 'except'],
#  ['told', 'would', 'great', 'would', 'w'],
#  ['new',
#   'york',
#   'post',
#   'trust',
#   'news',
#   'sourc',
#   'report',
#   'dead',
#   'voter',
#   'mail',
#   'ballot',
#   'biden',
#   'new',
#   'york',
#   'stori'],
#  ['pm', 'gmt', 'lead', 'pa', 'cut', 'reduc', 'gt', 'hour', 'still'],
#  ['didnt', 'look'],
#  ['know', 'fuck', 'bruh'],
#  ['think', 'wake', 'know', 'presid', 'straight'],
#  ['real'],
#  ['unit', 'state', 'postal', 'servic'],
#  ['communist', 'parti', 'done', 'u', 'need', 'new', 'one', 'right', 'one'],
#  ['say',
#   'tradit',
#   'sinc',
#   'germani',
#   'wir',
#   'haben',
#   'von',
#   'nicht',
#   'gewusst',
#   'know',
#   'anyth'],
#  ['imagin',
#   'realli',
#   'believ',
#   'one',
#   'two',
#   'major',
#   'parti',
#   'le',
#   'corrupt',
#   'two',
#   'parti',
#   'system'],
#  ['win', 'would', 'due', 'popular', 'accept', 'public'],
#  ['lol',
#   'find',
#   'real',
#   'pickl',
#   'ga',
#   'amp',
#   'pa',
#   'like',
#   'announc',
#   'winner'],
#  ['win', 'would', 'due', 'popular', 'accept', 'public', 'would', 'du'],
#  ['updat', 'state', 'continu', 'count', 'urg'],
#  ['seriou', 'obvious', 'fake', 'fd', 'see', 'plain', 'day', 'fake', 'one'],
#  ['go',
#   'forward',
#   'elect',
#   'mostli',
#   'vote',
#   'mail',
#   'person',
#   'dropoff',
#   'note',
#   'dropoff',
#   'mean',
#   'verifi',
#   'v'],
#  ['mean', 'happen', 'stay', 'white', 'hous'],
#  ['oh', 'ironi', 'flip', 'state', 'result', 'postal', 'activ', 'enc'],
#  ['math', 'k', 'mail', 'count', 'go', 'that', 'k', 'gain', 'k', 'biden'],
#  ['mr', 'save', 'plea'],
#  ['nicola',
#   'ceauescu',
#   'found',
#   'run',
#   'friend',
#   'last',
#   'day',
#   'helicopt',
#   'evacu',
#   'roof'],
#  ['say',
#   'honor',
#   'request',
#   'ahead',
#   'nv',
#   'az',
#   'want',
#   'u',
#   'stop',
#   'count',
#   'let'],
#  ['nice'],
#  ['u', 'depart', 'state'],
#  ['peopl',
#   'differ',
#   'airpod',
#   'everi',
#   'day',
#   'week',
#   'grind',
#   'ever',
#   'drink',
#   'coffe'],
#  ['report'],
#  ['dr', 'fauci', 'round', 'white', 'hous', 'tomorrow'],
#  ['come', 'fuckington', 'america', 'behind'],
#  ['think', 'might', 'care', 'dont', 'think', 'anyth'],
#  ['thing', 'jon', 'go', 'take', 'mantl', 'tonight', 'howev', 'az', 'wi'],
#  ['tv', 'pre'],
#  ['floyd', 'adjust', 'came', 'lean', 'almost'],
#  ['here',
#   'hope',
#   'correct',
#   'anyon',
#   'actual',
#   'seen',
#   'trump',
#   'today',
#   'seem',
#   'vanish',
#   'hide',
#   'probabl'],
#  ['flimflamm',
#   'never',
#   'fear',
#   'dead',
#   'spend',
#   'week',
#   'togeth',
#   'sinc',
#   'lockdown',
#   'come',
#   'flimflam'],
#  ['amount',
#   'wind',
#   'thunder',
#   'outsid',
#   'mean',
#   'retir',
#   'sleep',
#   'hope',
#   'wake',
#   'hour'],
#  ['math', 'k', 'mail', 'count', 'go', 'that'],
#  ['final',
#   'someon',
#   'said',
#   'thing',
#   'dear',
#   'american',
#   'thing',
#   'even',
#   'tri',
#   'go',
#   'war'],
#  ['take', 'hold', 'west', 'go', 'get', 'done'],
#  ['joe',
#   'biden',
#   'break',
#   'donald',
#   'trump',
#   'climat',
#   'chang',
#   'po',
#   'via',
#   'biden'],
#  ['differ', 'biden', 'go', 'win'],
#  ['chanc', 'overtak', 'pa', 'rise', 'differ', 'k', 'k', 'ballot', 'left'],
#  ['alway'],
#  ['powel', 'divorc'],
#  ['liar', 'look', 'economi', 'number', 'februari', 'look', 'obama', 'labor'],
#  ['get', 'choos', 'stop', 'count', 'stop', 'win'],
#  ['q',
#   'result',
#   'nc',
#   'ga',
#   'pa',
#   'come',
#   'soon',
#   'take',
#   'lead',
#   'democrat',
#   'switch'],
#  ['biden',
#   'go',
#   'add',
#   'new',
#   'cabinet',
#   'posit',
#   'secretari',
#   'mental',
#   'health'],
#  ['make', 'mistak', 'vote'],
#  ['troop',
#   'remain',
#   'bomb',
#   'keep',
#   'fall',
#   'sanction',
#   'continu',
#   'woman',
#   'child',
#   'keep'],
#  ['fair', 'outcom', 'mail', 'vote', 'real', 'vote', 'show', 'clear', 'differ'],
#  ['love', 'keep', 'u', 'wait'],
#  ...]

# %%
Biden_words=[]
for words in Cleaned_Tweet:
    for word in words:
        Biden_words.append("".join(word))
pd.value_counts(Biden_words).nlargest(50)
# Out:
# vote        20720
# trump       18325
# biden       17978
# win         17601
# presid      10053
# go           9685
# joe          9536
# u            9357
# amp          8206
# like         7721
# get          6886
# state        6100
# peopl        5969
# america      5551
# count        5522
# say          5464
# need         4971
# support      4814
# know         4794
# one          4754
# american     4573
# let          4553
# day          4547
# want         4488
# make         4380
# think        4241
# time         4159
# would        4029
# call         3991
# look         3913
# lead         3826
# right        3680
# hope         3588
# see          3562
# come         3531
# take         3514
# good         3465
# still        3461
# year         3430
# elect        3306
# today        3242
# plea         3134
# even         3011
# poll         2904
# new          2895
# democrat     2884
# im           2859
# watch        2794
# result       2778
# campaign     2743
# dtype: int64

# %%
#now we need to remove the stop_words again because after stemming the words coverting to general verse
more_stop_words=['vote','say','would',"u","im"]
stop_words=stop_words+more_stop_words

Biden_words=[words for words in Biden_words if words not in stop_words]

# %%
Most_Common_Biden=Counter(Biden_words).most_common(200)

# %% [markdown]
# for the word cloud will only show the top 200 words that shows most occursionally.

# %%
#list that will use for the word cloud
word_cloud_Biden=[]
for words in Most_Common_Biden:
    word_cloud_Biden.append(words[0])
#word_cloud_Biden

# %%
#word cloud

#load the image with Biden
Image_array = np.array(Image.open(r'C:\Users\brand\Desktop\Make More Difference\2020 Election Project\Image\Biden.png'))

image_color = ImageColorGenerator(Image_array )


wc = WordCloud(mask=Image_array, color_func=image_color, background_color='white').generate(' '.join(word_cloud_Biden))
plt.figure(figsize = (12, 12), facecolor="None") 
plt.imshow(wc,interpolation='bilinear') 
plt.axis("off") 
plt.title("WordCloud of Biden Tweets")
plt.show()

# %% [markdown]
# The wordcloud can help us to see what is the hottest topics will mentioned under the biden's hastages.

# %% [markdown]
# ## Sentiment Analyis
#
# As for tweeter, we can use a open-source library "MonkeyLearn" will be used for this analysis process
